# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.join("./", "..", ".."))

# %%
config_path = './../../configs/vae.json'
import json
from types import SimpleNamespace
config = SimpleNamespace(**json.load(open(config_path, 'r')))

# %%
# X = pd.read_csv('./../../Data/breast/breast.csv', usecols = ['radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst']).to_numpy()

# def f(x):
#     if x == 'M':
#         return 1
#     else:
#         return 0
# y = pd.read_csv('./../../Data/breast/breast.csv', usecols = ['diagnosis'])['diagnosis'].apply(f).to_numpy()

# X = X - np.min(X, axis = 0)
# X = X / np.max(X, axis = 0)


# np.savetxt("./../../Data/breast/X.tsv", X, delimiter="\t")
# np.savetxt("./../../Data/breast/y.tsv", y, delimiter="\t")

# %%
config
# Out:
# namespace(features_path='./Reproduction/Housing/Data/X.tsv',
#           labels_path='./Reproduction/Housing/Data/y.tsv',
#           model_dir='./Models/',
#           batch_size=128,
#           min_epochs=200,
#           stopping_epochs=25,
#           tol=0.001,
#           eval_freq=1,
#           lr=0.001)

# %%
config.features_path = "./../../Data/breast/X.tsv"
config.labels_path = "./../../Data/breast/y.tsv"
config.model_dir = './../../Models'
config.dataset = "breast"
config.lr = 0.005

# %%
from Model import *
model = Model.Initialize('vae', None, pretrained_path=None, config=config)
# Out:
# Wait, the model is in training
# Epoch 1 elbo_train -28.2496395111084 elbo_val -14.867377281188965
# Epoch 1 cost_train 168.16010297165073 cost_val 125.82831907891418
# Epoch 1 tc_train 4.663682115351412 tc_val 3.6986980599241734
# ###
# Saving the best model at epoch 1
# Epoch 2 elbo_train -1.4925951957702637 elbo_val 8.590394735336304
# Epoch 2 cost_train 133.49632591928824 cost_val 97.76211512814345
# Epoch 2 tc_train 4.400124357450599 tc_val 3.5450836621159914
# ###
# Saving the best model at epoch 2
# Epoch 3 elbo_train 15.28453803062439 elbo_val 22.345558166503906
# Epoch 3 cost_train 110.64846578023949 cost_val 84.24498668887021
# Epoch 3 tc_train 4.197766793695463 tc_val 3.553018161845804
# ###
# Saving the best model at epoch 3
# Epoch 4 elbo_train 19.675636768341064 elbo_val 24.260194778442383
# Epoch 4 cost_train 105.6712365995395 cost_val 81.34587441016822
# Epoch 4 tc_train 4.178229112262685 tc_val 3.52020230628702
# ###
# Saving the best model at epoch 4
# Epoch 5 elbo_train 22.6641583442688 elbo_val 26.189602851867676
# Epoch 5 cost_train 100.77682350808716 cost_val 77.95523628944642
# Epoch 5 tc_train 4.114699395078532 tc_val 3.4714946380438034
# ###
# Saving the best model at epoch 5
# Epoch 6 elbo_train 26.38419246673584 elbo_val 27.705904960632324
# Epoch 6 cost_train 94.95178874996036 cost_val 76.44351688054846
# Epoch 6 tc_train 4.044532707223207 tc_val 3.471647394706026
# ###
# Saving the best model at epoch 6
# Epoch 7 elbo_train 29.03170919418335 elbo_val 33.342519760131836
# Epoch 7 cost_train 91.67876166680094 cost_val 71.06558332838908
# Epoch 7 tc_train 4.02368236203281 tc_val 3.4802701029506973
# ###
# Saving the best model at epoch 7
# Epoch 8 elbo_train 31.642526149749756 elbo_val 35.04282569885254
# Epoch 8 cost_train 88.63712250576587 cost_val 69.05388768403273
# Epoch 8 tc_train 4.009321621850521 tc_val 3.4698904460961755
# ###
# Saving the best model at epoch 8
# Epoch 9 elbo_train 33.42030334472656 elbo_val 36.85419464111328
# Epoch 9 cost_train 86.37055581641998 cost_val 67.18238197403369
# Epoch 9 tc_train 3.993028638704885 tc_val 3.4678858871715654
# ###
# Saving the best model at epoch 9
# Epoch 10 elbo_train 33.5256233215332 elbo_val 36.73008155822754
# Epoch 10 cost_train 86.28078745528566 cost_val 66.85515786741763
# Epoch 10 tc_train 3.9935470258939616 tc_val 3.4528413141881726
# ###
# Epoch 11 elbo_train 34.38934135437012 elbo_val 38.988399505615234
# Epoch 11 cost_train 85.28682510376164 cost_val 64.8637248297654
# Epoch 11 tc_train 3.9892055486043922 tc_val 3.4617374778460217
# ###
# Saving the best model at epoch 11
# Epoch 12 elbo_train 34.9710636138916 elbo_val 38.265241622924805
# Epoch 12 cost_train 84.82502500926583 cost_val 65.74348564765191
# Epoch 12 tc_train 3.993202954105248 tc_val 3.466957575685891
# ###
# Epoch 13 elbo_train 34.2262020111084 elbo_val 38.05261039733887
# Epoch 13 cost_train 85.37979223417766 cost_val 65.91974702265641
# Epoch 13 tc_train 3.986866474842869 tc_val 3.465745247333176
# ###
# Epoch 14 elbo_train 36.514580726623535 elbo_val 39.27336120605469
# Epoch 14 cost_train 83.52433110731403 cost_val 64.72127564101754
# Epoch 14 tc_train 4.001297061131252 tc_val 3.466487894902408
# ###
# Saving the best model at epoch 14
# Epoch 15 elbo_train 37.423665046691895 elbo_val 40.19218444824219
# Epoch 15 cost_train 82.18997577816282 cost_val 63.554742819257854
# Epoch 15 tc_train 3.98712136082849 tc_val 3.4582309089166676
# ###
# Saving the best model at epoch 15
# Epoch 16 elbo_train 34.48699188232422 elbo_val 37.216243743896484
# Epoch 16 cost_train 85.03639300473095 cost_val 66.63096842375154
# Epoch 16 tc_train 3.9841128295685055 tc_val 3.461573738921601
# ###
# Epoch 17 elbo_train 35.965641021728516 elbo_val 39.627180099487305
# Epoch 17 cost_train 83.94315443659922 cost_val 64.57261944082606
# Epoch 17 tc_train 3.9969598486109246 tc_val 3.473326651343779
# ###
# Epoch 18 elbo_train 36.753257751464844 elbo_val 38.730812072753906
# Epoch 18 cost_train 82.8635430322585 cost_val 65.22743159730031
# Epoch 18 tc_train 3.9872266927907782 tc_val 3.465274789001807
# ###
# Epoch 19 elbo_train 36.66942119598389 elbo_val 39.05053901672363
# Epoch 19 cost_train 82.64081094561072 cost_val 64.86636481267055
# Epoch 19 tc_train 3.9770077380531537 tc_val 3.463896794313139
# ###
# Epoch 20 elbo_train 35.098700523376465 elbo_val 35.93564987182617
# Epoch 20 cost_train 84.38027459553147 cost_val 68.36610873351157
# Epoch 20 tc_train 3.9826325039635977 tc_val 3.4767252868445917
# ###
# Epoch 21 elbo_train 34.85727787017822 elbo_val 39.43581199645996
# Epoch 21 cost_train 84.87706433288324 cost_val 64.78774905939082
# Epoch 21 tc_train 3.991144740102049 tc_val 3.4741187018616926
# ###
# Epoch 22 elbo_train 35.38553428649902 elbo_val 39.418474197387695
# Epoch 22 cost_train 84.33797598371632 cost_val 64.56067256347282
# Epoch 22 tc_train 3.9907836756738444 tc_val 3.465971558695351
# ###
# Epoch 23 elbo_train 34.94986057281494 elbo_val 39.372806549072266
# Epoch 23 cost_train 84.39530759500555 cost_val 64.59364276116862
# Epoch 23 tc_train 3.9781722722606827 tc_val 3.4655483103413633
# ###
# Epoch 24 elbo_train 36.46061420440674 elbo_val 40.145063400268555
# Epoch 24 cost_train 83.07796485477026 cost_val 63.865672380519406
# Epoch 24 tc_train 3.9846193019725664 tc_val 3.4670245260262655
# ###
# Epoch 25 elbo_train 37.836283683776855 elbo_val 40.278526306152344
# Epoch 25 cost_train 81.75533413697059 cost_val 63.65646312718214
# Epoch 25 tc_train 3.986387260691582 tc_val 3.4644996477778163
# ###
# Saving the best model at epoch 25
# Epoch 26 elbo_train 37.80163860321045 elbo_val 39.67189598083496
# Epoch 26 cost_train 81.62667678124613 cost_val 64.53665153327427
# Epoch 26 tc_train 3.980943846148553 tc_val 3.4736182504703073
# ###
# Epoch 27 elbo_train 37.730356216430664 elbo_val 41.080928802490234
# Epoch 27 cost_train 81.78262385615861 cost_val 63.139090184034345
# Epoch 27 tc_train 3.9837660024196424 tc_val 3.4740006328841524
# ###
# Saving the best model at epoch 27
# Epoch 28 elbo_train 38.39340686798096 elbo_val 41.233537673950195
# Epoch 28 cost_train 81.22216256573157 cost_val 62.69893688367966
# Epoch 28 tc_train 3.987185647790417 tc_val 3.464415818587662
# ###
# Saving the best model at epoch 28
# Epoch 29 elbo_train 39.338351249694824 elbo_val 41.69704818725586
# Epoch 29 cost_train 80.17664005724849 cost_val 62.22689222246625
# Epoch 29 tc_train 3.983833043564777 tc_val 3.4641313469907367
# ###
# Saving the best model at epoch 29
# Epoch 30 elbo_train 37.58492088317871 elbo_val 39.04562568664551
# Epoch 30 cost_train 81.90019911800451 cost_val 65.0970547290454
# Epoch 30 tc_train 3.982837333372774 tc_val 3.4714226805230304
# ###
# Epoch 31 elbo_train 36.038479804992676 elbo_val 38.95892524719238
# Epoch 31 cost_train 83.58234741225633 cost_val 65.24775767714699
# Epoch 31 tc_train 3.987360907241633 tc_val 3.4735560974779793
# ###
# Epoch 32 elbo_train 36.35198497772217 elbo_val 41.15782928466797
# Epoch 32 cost_train 83.40372631585647 cost_val 63.11300740140776
# Epoch 32 tc_train 3.991857043119289 tc_val 3.4756945562025248
# ###
# Epoch 33 elbo_train 36.88966655731201 elbo_val 39.893070220947266
# Epoch 33 cost_train 82.49727513938166 cost_val 64.15201253926726
# Epoch 33 tc_train 3.9795647232231217 tc_val 3.4681694253404842
# ###
# Epoch 34 elbo_train 38.59544372558594 elbo_val 39.49240303039551
# Epoch 34 cost_train 80.6729349676194 cost_val 64.63127175579876
# Epoch 34 tc_train 3.9756126231068443 tc_val 3.4707891595398093
# ###
# Epoch 35 elbo_train 38.325926780700684 elbo_val 40.85280990600586
# Epoch 35 cost_train 81.0657843492478 cost_val 63.34856648130942
# Epoch 35 tc_train 3.979723704331616 tc_val 3.473379212910509
# ###
# Epoch 36 elbo_train 38.300533294677734 elbo_val 41.639129638671875
# Epoch 36 cost_train 81.32699337562352 cost_val 62.43325245914638
# Epoch 36 tc_train 3.987584222343375 tc_val 3.4690794032606087
# ###
# Epoch 37 elbo_train 38.99185276031494 elbo_val 43.08550453186035
# Epoch 37 cost_train 80.55055609346329 cost_val 60.80528111592403
# Epoch 37 tc_train 3.9847469617926077 tc_val 3.4630261882594793
# ###
# Saving the best model at epoch 37
# Epoch 38 elbo_train 39.53470993041992 elbo_val 41.464651107788086
# Epoch 38 cost_train 79.97627444453057 cost_val 62.59293140486406
# Epoch 38 tc_train 3.983699479165016 tc_val 3.4685860837550715
# ###
# Epoch 39 elbo_train 38.81457805633545 elbo_val 42.20204734802246
# Epoch 39 cost_train 80.58436416315224 cost_val 62.0137893790975
# Epoch 39 tc_train 3.97996474064959 tc_val 3.473861224237332
# ###
# Epoch 40 elbo_train 38.42831230163574 elbo_val 38.00753974914551
# Epoch 40 cost_train 81.11490640765172 cost_val 66.23821652110085
# Epoch 40 tc_train 3.984773956976249 tc_val 3.4748585423415452
# ###
# Epoch 41 elbo_train 37.23482131958008 elbo_val 40.68465995788574
# Epoch 41 cost_train 82.31478049814486 cost_val 63.73623564359796
# Epoch 41 tc_train 3.984986727257498 tc_val 3.480696520049457
# ###
# Epoch 42 elbo_train 37.9849739074707 elbo_val 42.24232292175293
# Epoch 42 cost_train 81.58890968031169 cost_val 61.9495962968741
# Epoch 42 tc_train 3.9857961195927465 tc_val 3.4730639739542344
# ###
# Epoch 43 elbo_train 37.9367561340332 elbo_val 40.654075622558594
# Epoch 43 cost_train 81.25901667141719 cost_val 63.70742727897129
# Epoch 43 tc_train 3.973192426848346 tc_val 3.4787167633843294
# ###
# Epoch 44 elbo_train 38.415886878967285 elbo_val 41.97855567932129
# Epoch 44 cost_train 80.91226523935498 cost_val 62.46175193736695
# Epoch 44 tc_train 3.977605070610742 tc_val 3.4813435872229412
# ###
# Epoch 45 elbo_train 38.81771945953369 elbo_val 41.57680130004883
# Epoch 45 cost_train 80.7295919959471 cost_val 62.79867252568519
# Epoch 45 tc_train 3.98491038184936 tc_val 3.4791824608578006
# ###
# Epoch 46 elbo_train 39.643160820007324 elbo_val 41.42019081115723
# Epoch 46 cost_train 79.87548295855896 cost_val 62.72466617706599
# Epoch 46 tc_train 3.983954792618877 tc_val 3.4714952329407742
# ###
# Epoch 47 elbo_train 37.834303855895996 elbo_val 40.82102584838867
# Epoch 47 cost_train 81.6181169982914 cost_val 63.718397895918955
# Epoch 47 tc_train 3.9817473618062467 tc_val 3.484647458143588
# ###
# Epoch 48 elbo_train 38.846689224243164 elbo_val 39.764657974243164
# Epoch 48 cost_train 80.82750766470953 cost_val 64.43227251035633
# Epoch 48 tc_train 3.989139896298423 tc_val 3.473231016153316
# ###
# Epoch 49 elbo_train 38.84126091003418 elbo_val 41.28384590148926
# Epoch 49 cost_train 80.62523127521494 cost_val 63.232109641292
# Epoch 49 tc_train 3.982216406174971 tc_val 3.4838651847593756
# ###
# Epoch 50 elbo_train 38.74718761444092 elbo_val 42.00289535522461
# Epoch 50 cost_train 80.48659334202293 cost_val 62.59531005439569
# Epoch 50 tc_train 3.974459365215461 tc_val 3.4866068469873435
# ###
# Epoch 51 elbo_train 38.64313793182373 elbo_val 40.27000045776367
# Epoch 51 cost_train 80.73954590423982 cost_val 64.3624782782496
# Epoch 51 tc_train 3.9794227945354512 tc_val 3.4877492912004424
# ###
# Epoch 52 elbo_train 39.32136058807373 elbo_val 42.16114807128906
# Epoch 52 cost_train 80.02336117265193 cost_val 62.22672502206537
# Epoch 52 tc_train 3.9781573920241886 tc_val 3.4795957697784807
# ###
# Epoch 53 elbo_train 39.911020278930664 elbo_val 40.54418182373047
# Epoch 53 cost_train 79.66267119573716 cost_val 63.61357364621033
# Epoch 53 tc_train 3.985789715822261 tc_val 3.4719251823313595
# ###
# Epoch 54 elbo_train 38.71592044830322 elbo_val 41.368452072143555
# Epoch 54 cost_train 80.7504976817384 cost_val 63.074211557906416
# Epoch 54 tc_train 3.9822139376680536 tc_val 3.481422121001666
# ###
# Epoch 55 elbo_train 39.04556941986084 elbo_val 41.676435470581055
# Epoch 55 cost_train 80.33852420452267 cost_val 62.70473957579986
# Epoch 55 tc_train 3.9794697874794505 tc_val 3.4793725015460306
# ###
# Epoch 56 elbo_train 39.12748336791992 elbo_val 40.758955001831055
# Epoch 56 cost_train 80.35578410141454 cost_val 63.673911044472064
# Epoch 56 tc_train 3.982775582311149 tc_val 3.4810955348767707
# ###
# Epoch 57 elbo_train 38.807634353637695 elbo_val 40.640960693359375
# Epoch 57 cost_train 80.56546137713626 cost_val 63.53067216413502
# Epoch 57 tc_train 3.9791031910257986 tc_val 3.4723877619164796
# ###
# Epoch 58 elbo_train 38.95946502685547 elbo_val 40.69681930541992
# Epoch 58 cost_train 80.42078726647735 cost_val 63.766118805357756
# Epoch 58 tc_train 3.9793417431110942 tc_val 3.4820979370259226
# ###
# Epoch 59 elbo_train 38.64310359954834 elbo_val 42.18417930603027
# Epoch 59 cost_train 80.86128391017135 cost_val 62.0765018516444
# Epoch 59 tc_train 3.983479583657323 tc_val 3.4753560385891555
# ###
# Epoch 60 elbo_train 38.74319648742676 elbo_val 42.18246269226074
# Epoch 60 cost_train 80.74160703370715 cost_val 62.23305242929382
# Epoch 60 tc_train 3.982826784037797 tc_val 3.4805171707184854
# ###
# Epoch 61 elbo_train 39.30036735534668 elbo_val 41.27322769165039
# Epoch 61 cost_train 80.13989512554372 cost_val 63.22207221384303
# Epoch 61 tc_train 3.9813420826963464 tc_val 3.4831766635164474
# ###
# Epoch 62 elbo_train 39.37230587005615 elbo_val 42.099647521972656
# Epoch 62 cost_train 80.04989138388864 cost_val 62.391830427686216
# Epoch 62 tc_train 3.980739908464826 tc_val 3.4830492649886287
# ###
# Epoch 63 elbo_train 39.801697731018066 elbo_val 42.695186614990234
# Epoch 63 cost_train 79.61540084953964 cost_val 61.75034200535781
# Epoch 63 tc_train 3.9805699526852565 tc_val 3.481517620678268
# ###
# Epoch 64 elbo_train 39.072678565979004 elbo_val 42.55844688415527
# Epoch 64 cost_train 80.30280451784992 cost_val 61.9803923584775
# Epoch 64 tc_train 3.979182769460964 tc_val 3.484627974754426
# ###
# Epoch 65 elbo_train 40.313565254211426 elbo_val 42.930641174316406
# Epoch 65 cost_train 79.13919917799906 cost_val 61.53232909911381
# Epoch 65 tc_train 3.981758814407016 tc_val 3.4820990091143402
# ###
# Epoch 66 elbo_train 40.141231536865234 elbo_val 41.240020751953125
# Epoch 66 cost_train 79.19066695739876 cost_val 63.05481575521877
# Epoch 66 tc_train 3.9777299498087997 tc_val 3.476494550239063
# ###
# Epoch 67 elbo_train 39.99083232879639 elbo_val 42.92069625854492
# Epoch 67 cost_train 79.43746935603527 cost_val 61.635571768923455
# Epoch 67 tc_train 3.980943389494388 tc_val 3.485208934248946
# ###
# Epoch 68 elbo_train 40.635191917419434 elbo_val 43.100515365600586
# Epoch 68 cost_train 78.83587461276974 cost_val 61.312484284995
# Epoch 68 tc_train 3.9823688843396394 tc_val 3.4804333216865198
# ###
# Saving the best model at epoch 68
# Epoch 69 elbo_train 40.582966804504395 elbo_val 42.01864051818848
# Epoch 69 cost_train 78.82543243784902 cost_val 62.40904692597607
# Epoch 69 tc_train 3.980279974745114 tc_val 3.480922914805485
# ###
# Epoch 70 elbo_train 40.46156883239746 elbo_val 42.82146453857422
# Epoch 70 cost_train 78.98521817813374 cost_val 61.95791101401766
# Epoch 70 tc_train 3.9815595670177064 tc_val 3.4926458517530627
# ###
# Epoch 71 elbo_train 40.37967014312744 elbo_val 42.20746612548828
# Epoch 71 cost_train 79.12925565317651 cost_val 62.244979150467685
# Epoch 71 tc_train 3.9836308598767984 tc_val 3.4817481758651985
# ###
# Epoch 72 elbo_train 39.4754753112793 elbo_val 42.89653778076172
# Epoch 72 cost_train 79.92337983039688 cost_val 61.45635225338054
# Epoch 72 tc_train 3.979961838055873 tc_val 3.478429667804742
# ###
# Epoch 73 elbo_train 39.21928882598877 elbo_val 42.48094367980957
# Epoch 73 cost_train 80.25192114847775 cost_val 62.29400514840736
# Epoch 73 tc_train 3.98237366581555 tc_val 3.4924982942738976
# ###
# Epoch 74 elbo_train 40.093971252441406 elbo_val 43.047760009765625
# Epoch 74 cost_train 79.34684461358972 cost_val 61.697821411144055
# Epoch 74 tc_train 3.9813605288677048 tc_val 3.4915193806969897
# ###
# Epoch 75 elbo_train 40.9632043838501 elbo_val 42.437692642211914
# Epoch 75 cost_train 78.38848870172365 cost_val 62.232199680842015
# Epoch 75 tc_train 3.978389769519125 tc_val 3.488996410768464
# ###
# Epoch 76 elbo_train 38.195096015930176 elbo_val 40.7976016998291
# Epoch 76 cost_train 81.05430742415608 cost_val 63.630320191463184
# Epoch 76 tc_train 3.9749801146695423 tc_val 3.480930729709743
# ###
# Epoch 77 elbo_train 38.901076316833496 elbo_val 41.608938217163086
# Epoch 77 cost_train 80.56056139631005 cost_val 63.127033521068995
# Epoch 77 tc_train 3.982054590438118 tc_val 3.4911990579410697
# ###
# Epoch 78 elbo_train 39.63174247741699 elbo_val 42.35817337036133
# Epoch 78 cost_train 79.90920281555016 cost_val 62.29529732149288
# Epoch 78 tc_train 3.9846981764322384 tc_val 3.488449023061807
# ###
# Epoch 79 elbo_train 40.397239685058594 elbo_val 42.24920654296875
# Epoch 79 cost_train 78.92704560101467 cost_val 62.25335689811201
# Epoch 79 tc_train 3.977476176202442 tc_val 3.483418781369359
# ###
# Epoch 80 elbo_train 39.77851486206055 elbo_val 43.03254699707031
# Epoch 80 cost_train 79.54934533166721 cost_val 61.40531422320029
# Epoch 80 tc_train 3.977595339790925 tc_val 3.481262040675687
# ###
# Epoch 81 elbo_train 40.71055793762207 elbo_val 42.98819351196289
# Epoch 81 cost_train 78.76925586643645 cost_val 61.71237429832421
# Epoch 81 tc_train 3.982660460135284 tc_val 3.4900189270095696
# ###
# Epoch 82 elbo_train 40.65761947631836 elbo_val 43.40341758728027
# Epoch 82 cost_train 78.84581700271653 cost_val 61.29838204103074
# Epoch 82 tc_train 3.9834478826344966 tc_val 3.4900599876103673
# ###
# Saving the best model at epoch 82
# Epoch 83 elbo_train 40.91719341278076 elbo_val 43.16563034057617
# Epoch 83 cost_train 78.5477740108934 cost_val 61.538961081160835
# Epoch 83 tc_train 3.9821655807891387 tc_val 3.4901530473912334
# ###
# Epoch 84 elbo_train 39.73536396026611 elbo_val 41.750478744506836
# Epoch 84 cost_train 79.7391250038573 cost_val 62.64759304591273
# Epoch 84 tc_train 3.9824829654707807 tc_val 3.479935726347319
# ###
# Epoch 85 elbo_train 40.20207595825195 elbo_val 42.65192222595215
# Epoch 85 cost_train 79.41103669210817 cost_val 61.87455307599431
# Epoch 85 tc_train 3.9871037550120043 tc_val 3.484215843398215
# ###
# Epoch 86 elbo_train 40.54596424102783 elbo_val 40.86437225341797
# Epoch 86 cost_train 78.91716941257995 cost_val 63.7662351900786
# Epoch 86 tc_train 3.9821044551202593 tc_val 3.487686914783219
# ###
# Epoch 87 elbo_train 39.64083671569824 elbo_val 40.732961654663086
# Epoch 87 cost_train 79.6411771060101 cost_val 63.71772419746633
# Epoch 87 tc_train 3.9760671273902783 tc_val 3.481689528404314
# ###
# Epoch 88 elbo_train 39.74056148529053 elbo_val 43.40998077392578
# Epoch 88 cost_train 79.58796448808098 cost_val 61.16231993044545
# Epoch 88 tc_train 3.9776175324457173 tc_val 3.4857433568123746
# ###
# Saving the best model at epoch 88
# Epoch 89 elbo_train 40.09911632537842 elbo_val 39.59828567504883
# Epoch 89 cost_train 79.23393579682553 cost_val 64.88000255674433
# Epoch 89 tc_train 3.9777684040734655 tc_val 3.482609607726439
# ###
# Epoch 90 elbo_train 39.150957107543945 elbo_val 40.85575294494629
# Epoch 90 cost_train 80.24639584863803 cost_val 63.890758201525884
# Epoch 90 tc_train 3.9799117652060656 tc_val 3.4915503715490726
# ###
# Epoch 91 elbo_train 38.93121528625488 elbo_val 39.968788146972656
# Epoch 91 cost_train 80.46551834317754 cost_val 64.87190362042409
# Epoch 91 tc_train 3.979891120981081 tc_val 3.4946897255798914
# ###
# Epoch 92 elbo_train 38.61401081085205 elbo_val 41.35798263549805
# Epoch 92 cost_train 80.95646863744088 cost_val 63.12901419753615
# Epoch 92 tc_train 3.985682648276431 tc_val 3.482899894434473
# ###
# Epoch 93 elbo_train 39.654852867126465 elbo_val 42.33270454406738
# Epoch 93 cost_train 79.65500443750568 cost_val 62.0811991261356
# Epoch 93 tc_train 3.976995243487738 tc_val 3.4804634556734326
# ###
# Epoch 94 elbo_train 40.3738317489624 elbo_val 42.19775390625
# Epoch 94 cost_train 78.90903089321067 cost_val 62.501816694323196
# Epoch 94 tc_train 3.976095421405769 tc_val 3.489985686685773
# ###
# Epoch 95 elbo_train 40.62783241271973 elbo_val 41.69946479797363
# Epoch 95 cost_train 78.68374633148923 cost_val 62.94079856966926
# Epoch 95 tc_train 3.9770526248069658 tc_val 3.48800877892143
# ###
# Epoch 96 elbo_train 40.37678527832031 elbo_val 43.52331733703613
# Epoch 96 cost_train 79.09401951308824 cost_val 60.86862089923826
# Epoch 96 tc_train 3.9823601597136182 tc_val 3.4797312745424795
# ###
# Saving the best model at epoch 96
# Epoch 97 elbo_train 40.85012149810791 elbo_val 43.019792556762695
# Epoch 97 cost_train 78.5786435494341 cost_val 61.68127642201505
# Epoch 97 tc_train 3.9809588349180673 tc_val 3.4900356326259248
# ###
# Epoch 98 elbo_train 40.49839210510254 elbo_val 43.14361381530762
# Epoch 98 cost_train 79.00464146680667 cost_val 61.57782510464477
# Epoch 98 tc_train 3.983434452396974 tc_val 3.49071463066508
# ###
# Epoch 99 elbo_train 41.13465118408203 elbo_val 42.18763542175293
# Epoch 99 cost_train 78.34918687740996 cost_val 62.43708415099304
# Epoch 99 tc_train 3.982794602049733 tc_val 3.4874906524248654
# ###
# Epoch 100 elbo_train 40.20323371887207 elbo_val 43.67616271972656
# Epoch 100 cost_train 79.20347606359151 cost_val 60.83767525509951
# Epoch 100 tc_train 3.980223659415453 tc_val 3.483794599160869
# ###
# Saving the best model at epoch 100
# Epoch 101 elbo_train 40.923349380493164 elbo_val 41.84946632385254
# Epoch 101 cost_train 78.54322577363301 cost_val 62.626022185507104
# Epoch 101 tc_train 3.9822191718042057 tc_val 3.4825162836453214
# ###
# Epoch 102 elbo_train 40.353806495666504 elbo_val 43.42568016052246
# Epoch 102 cost_train 79.04757026568446 cost_val 61.218883190988166
# Epoch 102 tc_train 3.9800458920450317 tc_val 3.488152111717021
# ###
# Epoch 103 elbo_train 40.859785079956055 elbo_val 43.76528549194336
# Epoch 103 cost_train 78.52594862178609 cost_val 60.76442437742252
# Epoch 103 tc_train 3.9795244567247376 tc_val 3.484323662312196
# ###
# Saving the best model at epoch 103
# Epoch 104 elbo_train 40.64681625366211 elbo_val 42.528249740600586
# Epoch 104 cost_train 78.73395775371425 cost_val 62.16836056032323
# Epoch 104 tc_train 3.9793591335792122 tc_val 3.4898870100307935
# ###
# Epoch 105 elbo_train 40.753427505493164 elbo_val 42.65499687194824
# Epoch 105 cost_train 78.71139042079474 cost_val 61.98392753179896
# Epoch 105 tc_train 3.98216059754293 tc_val 3.4879641467915734
# ###
# Epoch 106 elbo_train 40.68868637084961 elbo_val 42.23526191711426
# Epoch 106 cost_train 78.78311639826748 cost_val 62.4076772015011
# Epoch 106 tc_train 3.982393425637236 tc_val 3.4880979706205117
# ###
# Epoch 107 elbo_train 40.13035488128662 elbo_val 40.436201095581055
# Epoch 107 cost_train 79.3170893994122 cost_val 64.10715877102679
# Epoch 107 tc_train 3.9815814760232944 tc_val 3.4847786622202612
# ###
# Epoch 108 elbo_train 39.980326652526855 elbo_val 40.94316482543945
# Epoch 108 cost_train 79.493505935097 cost_val 63.732602390522025
# Epoch 108 tc_train 3.982461086254129 tc_val 3.4891922405320495
# ###
# Epoch 109 elbo_train 40.48030757904053 elbo_val 41.63610076904297
# Epoch 109 cost_train 78.92918640017622 cost_val 62.84353901413843
# Epoch 109 tc_train 3.980316465973892 tc_val 3.4826546594393797
# ###
# Epoch 110 elbo_train 39.74666500091553 elbo_val 42.5528621673584
# Epoch 110 cost_train 79.62659518205847 cost_val 62.25643696315683
# Epoch 110 tc_train 3.9791086727657996 tc_val 3.493643304350508
# ###
# Epoch 111 elbo_train 40.152567863464355 elbo_val 42.70174980163574
# Epoch 111 cost_train 79.31760741799587 cost_val 61.73034386460741
# Epoch 111 tc_train 3.982339176048674 tc_val 3.4810697888747715
# ###
# Epoch 112 elbo_train 40.70026111602783 elbo_val 41.98825645446777
# Epoch 112 cost_train 78.75351905813517 cost_val 62.3677439939003
# Epoch 112 tc_train 3.9817926724721 tc_val 3.4785333482789356
# ###
# Epoch 113 elbo_train 40.466087341308594 elbo_val 43.50420951843262
# Epoch 113 cost_train 79.02042295537107 cost_val 61.156544430255494
# Epoch 113 tc_train 3.9828836765559887 tc_val 3.4886917982896035
# ###
# Epoch 114 elbo_train 41.02932167053223 elbo_val 42.620121002197266
# Epoch 114 cost_train 78.34631195378842 cost_val 62.24795935847129
# Epoch 114 tc_train 3.979187787477355 tc_val 3.495602678688952
# ###
# Epoch 115 elbo_train 40.4483642578125 elbo_val 42.81689453125
# Epoch 115 cost_train 79.05438120703674 cost_val 61.67711924082865
# Epoch 115 tc_train 3.9834248488283084 tc_val 3.4831337924026218
# ###
# Epoch 116 elbo_train 40.8392915725708 elbo_val 41.68911361694336
# Epoch 116 cost_train 78.66905393678792 cost_val 62.67896966795003
# Epoch 116 tc_train 3.983611516978624 tc_val 3.4789361094964466
# ###
# Epoch 117 elbo_train 40.329084396362305 elbo_val 42.938772201538086
# Epoch 117 cost_train 79.08511759758578 cost_val 61.682394935970486
# Epoch 117 tc_train 3.98047339979827 tc_val 3.4873722379169525
# ###
# Epoch 118 elbo_train 40.99623966217041 elbo_val 42.366132736206055
# Epoch 118 cost_train 78.45016174584391 cost_val 62.134261566600834
# Epoch 118 tc_train 3.981546713600478 tc_val 3.4833464767602296
# ###
# Epoch 119 elbo_train 40.45752716064453 elbo_val 42.63753318786621
# Epoch 119 cost_train 78.8876019399707 cost_val 61.75139458581946
# Epoch 119 tc_train 3.978170970020507 tc_val 3.4796309257895226
# ###
# Epoch 120 elbo_train 40.79821491241455 elbo_val 43.130231857299805
# Epoch 120 cost_train 78.55769053170783 cost_val 61.35147301777422
# Epoch 120 tc_train 3.9785301814707466 tc_val 3.482723495835801
# ###
# Epoch 121 elbo_train 40.15804481506348 elbo_val 43.258108139038086
# Epoch 121 cost_train 79.29719470873111 cost_val 61.26712330940265
# Epoch 121 tc_train 3.9818413174598195 tc_val 3.4841743816146913
# ###
# Epoch 122 elbo_train 40.75983905792236 elbo_val 39.11298179626465
# Epoch 122 cost_train 78.69105542106638 cost_val 65.6085781999478
# Epoch 122 tc_train 3.981696482632958 tc_val 3.4907186665404146
# ###
# Epoch 123 elbo_train 39.026543617248535 elbo_val 41.36840057373047
# Epoch 123 cost_train 80.46716008668476 cost_val 63.51495063909612
# Epoch 123 tc_train 3.983123456797776 tc_val 3.4961117070942196
# ###
# Epoch 124 elbo_train 40.025957107543945 elbo_val 42.70232391357422
# Epoch 124 cost_train 79.65011896438452 cost_val 62.10693747782314
# Epoch 124 tc_train 3.9892025357309486 tc_val 3.493642046379912
# ###
# Epoch 125 elbo_train 39.82190418243408 elbo_val 41.42012977600098
# Epoch 125 cost_train 79.77575755155563 cost_val 63.20542286621384
# Epoch 125 tc_train 3.9865887244663236 tc_val 3.4875184214071604
# ###
# Epoch 126 elbo_train 39.820438385009766 elbo_val 42.710025787353516
# Epoch 126 cost_train 79.52118306928031 cost_val 61.9199560380242
# Epoch 126 tc_train 3.9780540484763356 tc_val 3.487666060845924
# ###
# Epoch 127 elbo_train 40.259077072143555 elbo_val 43.33051681518555
# Epoch 127 cost_train 79.21061688690708 cost_val 61.21758054292092
# Epoch 127 tc_train 3.982323131968354 tc_val 3.484936578603549
# ###
# Epoch 128 elbo_train 40.445719718933105 elbo_val 42.2918643951416
# Epoch 128 cost_train 79.00426981045997 cost_val 62.13946814023289
# Epoch 128 tc_train 3.9816663176464364 tc_val 3.4810444178458164
# ###
# Epoch 129 elbo_train 40.2874116897583 elbo_val 42.39760208129883
# Epoch 129 cost_train 79.11935181288581 cost_val 62.01826254340596
# Epoch 129 tc_train 3.980225450088137 tc_val 3.4805288208234932
# ###
# Epoch 130 elbo_train 40.40341567993164 elbo_val 43.25510787963867
# Epoch 130 cost_train 79.09331692493319 cost_val 61.3347458852561
# Epoch 130 tc_train 3.983224420162162 tc_val 3.4863284588298256
# ###
# Epoch 131 elbo_train 41.017160415649414 elbo_val 41.93009376525879
# Epoch 131 cost_train 78.44853011829613 cost_val 62.61312658179425
# Epoch 131 tc_train 3.982189684464852 tc_val 3.484774011568435
# ###
# Epoch 132 elbo_train 40.496689796447754 elbo_val 41.748456954956055
# Epoch 132 cost_train 78.83726833512141 cost_val 62.62671206038519
# Epoch 132 tc_train 3.977798604385639 tc_val 3.479172300511375
# ###
# Epoch 133 elbo_train 40.33917999267578 elbo_val 42.09704399108887
# Epoch 133 cost_train 79.00784717856963 cost_val 62.37117498867111
# Epoch 133 tc_train 3.9782342390415137 tc_val 3.482273965991999
# ###
# Epoch 134 elbo_train 41.15296745300293 elbo_val 43.359670639038086
# Epoch 134 cost_train 78.26192898819914 cost_val 61.392433632371414
# Epoch 134 tc_train 3.980496548040069 tc_val 3.4917368090469836
# ###
# Epoch 135 elbo_train 41.31518840789795 elbo_val 42.47163772583008
# Epoch 135 cost_train 78.09646915007316 cost_val 62.16888892192888
# Epoch 135 tc_train 3.9803885852657035 tc_val 3.4880175549252987
# ###
# Epoch 136 elbo_train 40.31141662597656 elbo_val 42.71501159667969
# Epoch 136 cost_train 79.0669753206886 cost_val 61.82364950088436
# Epoch 136 tc_train 3.9792797315555055 tc_val 3.4846220365854683
# ###
# Epoch 137 elbo_train 40.572120666503906 elbo_val 42.998281478881836
# Epoch 137 cost_train 78.8543909160553 cost_val 61.45077363403256
# Epoch 137 tc_train 3.98088371941864 tc_val 3.4816351704304798
# ###
# Epoch 138 elbo_train 40.41445255279541 elbo_val 43.20939636230469
# Epoch 138 cost_train 78.92390425754104 cost_val 61.68068301250868
# Epoch 138 tc_train 3.9779452270112152 tc_val 3.4963359791604454
# ###
# Epoch 139 elbo_train 41.1127815246582 elbo_val 41.42190361022949
# Epoch 139 cost_train 78.19458099770482 cost_val 63.24517942237522
# Epoch 139 tc_train 3.9769120840787666 tc_val 3.4889027677534905
# ###
# Epoch 140 elbo_train 40.30917453765869 elbo_val 42.6562442779541
# Epoch 140 cost_train 79.1027924196967 cost_val 61.91682711786175
# Epoch 140 tc_train 3.9803988985785126 tc_val 3.485769046527195
# ###
# Epoch 141 elbo_train 40.913010597229004 elbo_val 41.51839256286621
# Epoch 141 cost_train 78.43723968754571 cost_val 62.98282172731833
# Epoch 141 tc_train 3.978341676159158 tc_val 3.483373809672818
# ###
# Epoch 142 elbo_train 40.375619888305664 elbo_val 40.92713928222656
# Epoch 142 cost_train 79.0283645966332 cost_val 63.79320254304167
# Epoch 142 tc_train 3.980132816164629 tc_val 3.4906780608422743
# ###
# Epoch 143 elbo_train 40.34341049194336 elbo_val 42.6612606048584
# Epoch 143 cost_train 79.11368613578742 cost_val 61.880244030637456
# Epoch 143 tc_train 3.981903220924359 tc_val 3.484716821183195
# ###
# Epoch 144 elbo_train 40.38278579711914 elbo_val 42.704166412353516
# Epoch 144 cost_train 79.03655511687451 cost_val 61.99033594519064
# Epoch 144 tc_train 3.9806446971331217 tc_val 3.489816745251472
# ###
# Epoch 145 elbo_train 40.73116493225098 elbo_val 42.967838287353516
# Epoch 145 cost_train 78.5765362158573 cost_val 61.6161448750948
# Epoch 145 tc_train 3.9769233716036094 tc_val 3.4861327720816107
# ###
# Epoch 146 elbo_train 41.21535110473633 elbo_val 43.51078224182129
# Epoch 146 cost_train 78.21553361110853 cost_val 61.122930955266234
# Epoch 146 tc_train 3.9810294905281616 tc_val 3.487790439902917
# ###
# Epoch 147 elbo_train 41.14296054840088 elbo_val 42.38346290588379
# Epoch 147 cost_train 78.33925054592194 cost_val 62.203241929074466
# Epoch 147 tc_train 3.9827403698107604 tc_val 3.486223494498608
# ###
# Epoch 148 elbo_train 40.752400398254395 elbo_val 43.00485420227051
# Epoch 148 cost_train 78.71094845052038 cost_val 61.56089210826871
# Epoch 148 tc_train 3.9821116282924924 tc_val 3.4855248770179736
# ###
# Epoch 149 elbo_train 40.62282466888428 elbo_val 40.49218940734863
# Epoch 149 cost_train 78.86044682847702 cost_val 64.14174193006365
# Epoch 149 tc_train 3.9827757165787103 tc_val 3.487797711247076
# ###
# Epoch 150 elbo_train 39.76208972930908 elbo_val 42.50723838806152
# Epoch 150 cost_train 79.76945712043133 cost_val 62.43092096556899
# Epoch 150 tc_train 3.9843848949913463 tc_val 3.497938645121017
# ###
# Epoch 151 elbo_train 40.64894676208496 elbo_val 41.93476867675781
# Epoch 151 cost_train 78.83803881860376 cost_val 62.860984329231314
# Epoch 151 tc_train 3.982899519356291 tc_val 3.493191766866304
# ###
# Epoch 152 elbo_train 40.582963943481445 elbo_val 41.35147666931152
# Epoch 152 cost_train 78.7883149320865 cost_val 63.402948482101706
# Epoch 152 tc_train 3.9790426291855976 tc_val 3.4918141717137745
# ###
# Epoch 153 elbo_train 40.19182586669922 elbo_val 42.94641876220703
# Epoch 153 cost_train 79.28952973034237 cost_val 61.615296344146245
# Epoch 153 tc_train 3.9827118532347194 tc_val 3.4853905035451094
# ###
# Epoch 154 elbo_train 40.49483680725098 elbo_val 40.05431938171387
# Epoch 154 cost_train 78.95749273516739 cost_val 64.26999451973913
# Epoch 154 tc_train 3.9817443180806125 tc_val 3.4774771300484333
# ###
# Epoch 155 elbo_train 39.70793151855469 elbo_val 43.201581954956055
# Epoch 155 cost_train 79.69101860521755 cost_val 61.70843446735438
# Epoch 155 tc_train 3.9799650041257406 tc_val 3.497000547410348
# ###
# Epoch 156 elbo_train 40.30862522125244 elbo_val 41.86594772338867
# Epoch 156 cost_train 78.95562559670695 cost_val 62.55522979184824
# Epoch 156 tc_train 3.9754750272653134 tc_val 3.480705917174564
# ###

# %%
x = pd.read
data_rep = model.Encode(x)

# %%
plt.scatter(data_rep[:,0], data_rep[:,1])
plt.show()
